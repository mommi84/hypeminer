# %%
from youtubesearchpython import VideosSearch
import spacy
import youtube_dl
import webvtt
import html
import os

nlp = spacy.load('en_core_web_lg')

# %%
def to_vtt_filename(filename):
    spl = filename.split('.')
    return '.'.join(spl[:-1]) + '.en.vtt'


def fetch_transcription_file(youtube_id):
    ydl_opts = {
        'writeinfojson': 'info.json',
        'writesubtitles': True,
        'writeautomaticsub': True,
        'subtitleslangs': ['en'],
        'subtitlesformat': 'vtt',
        'skip_download': True,
        'writeinfojson': False,
        'quiet': True,
    }
    with youtube_dl.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(f"https://www.youtube.com/watch?v={youtube_id}", download=True)
        fn = ydl.prepare_filename(info)

    vtt_file = f"subtitles/{youtube_id}.vtt"
    os.replace(to_vtt_filename(fn), vtt_file)
    return vtt_file

def to_transcription(vtt_file):
    transcr_groups = [html.unescape(caption.text).strip().split('\n') for caption in webvtt.read(vtt_file)]
    transcr_lines = []
    for line in [x.strip() for x in sum(transcr_groups, [])]:
        if line == "":
            continue
        if len(transcr_lines) == 0:
            transcr_lines.append(line)
        elif transcr_lines[-1] != line:
            transcr_lines.append(line)
    return ' '.join(transcr_lines)

def sentencise(text):
    return [f"{sent.text}." for sent in nlp(text).sents]

def to_days(wordy_time):
    if 'Streamed ' in wordy_time:
        wordy_time = wordy_time[9:]
    value = int(wordy_time.split(' ')[0])
    cases = {
        'minute': 1/(24*60),
        'hour': 1/24,
        'day': 1,
        'week': 7,
        'month': 30,
        'year': 365,
    }
    for word, k in cases.items():
        if word in wordy_time:
            return value * k
    raise Exception(f"Unit of time not understood: {wordy_time}")

def get_latest_videos(channel, days=7):
    video_search = VideosSearch(channel, limit=days*3)
    results = video_search.result()
    output = []
    for result in results['result']:
        try:
            days_old = to_days(result['publishedTime'])
        except TypeError: # upcoming stream
            continue
        if days_old <= days:
            output.append({'id': result['id'], 'days_old': days_old, 'metadata': result})
    return output

def process_video(video_id, show=False):
    if os.path.exists(f"subtitles/{video_id}.vtt"):
        vtt_file = f"subtitles/{video_id}.vtt"
        print(f"Subtitles found locally for video: {video_id}")
    else:
        vtt_file = fetch_transcription_file(video_id)
        print(f"Subtitles processed: {video_id}")
    transcription = to_transcription(vtt_file)
    sentences = sentencise(transcription)
    if show:
        print('\n\n'.join(sentences))
    return sentences

def process_channel(channel, days=7, show=False):
    print(f"Now processing channel: {channel}")
    if show:
        print('\n' + "-" * 100 + '\n')
    output = []
    for video in get_latest_videos(channel, days=days):
        try:
            video['subtitles'] = process_video(video['id'], show=show)
            video['channel'] = channel
            output.append(video)
        except FileNotFoundError:
            print(f"Subtitles not (yet) available for video: {video['id']}")
        if show:
            print('\n' + "-" * 100 + '\n')
    return output

# %%
def all_coin_mentions(coin, mentions):
    return sum([x for _, x in mentions[coin].items()], [])

# %%
channels = [
    'MyFinancialFriend', 'thekaleshow', 'AlexBeckersChannel', 'AltcoinDaily', 'CryptosRUs', 
    'OnlyTheSAVVY', 'MoneyZG', 'SheldonEvansx', 'MMCryptoTube', 'JasonPizzinoOfficial', 
    'FUDTV', 'BrianJungy', 'CryptoBanterGroup', 'JamieTree', 'UCjemQfjaXAzA-95RKoy9n_g', 
    'INEVITRADE', 'CoinBureau', 'TheCryptoLark',
]

data = []

for channel in channels:
    data += process_channel(channel, days=7)
# Out:
# Now processing channel: MyFinancialFriend
# Subtitles found locally for video: jWbUaR2VyDo
# Subtitles found locally for video: s7FcrGEfOKY
# Subtitles found locally for video: j-_c5je1whY
# Subtitles found locally for video: voisKBy0DiA
# Subtitles found locally for video: LHq_Cyuw3e0
# Subtitles found locally for video: ivBZNF22XgQ
# Subtitles found locally for video: rD1PvJLhm5g
# Subtitles found locally for video: RK0MrcKCwCE
# Subtitles found locally for video: cIjjA6B_Opw
# Subtitles found locally for video: Mv5PGtt_pD4
# Subtitles found locally for video: qy_hE0KhKe4
# Subtitles found locally for video: f65dTEmPv70
# Now processing channel: thekaleshow
# Subtitles processed: 8mFfGRjDr7k
# Subtitles found locally for video: WuTM4h_u58c
# Subtitles processed: TxRAux9Otyo
# Subtitles found locally for video: 4m6ndv8vRJI
# Subtitles found locally for video: D5RvMGj4IeU
# Subtitles found locally for video: 5ts98CchG20
# Now processing channel: AlexBeckersChannel
# Subtitles found locally for video: jLdF2qt_uWQ
# Subtitles found locally for video: aBUe1icpho0
# Now processing channel: AltcoinDaily
# Subtitles found locally for video: xJ_dBjTykoQ
# Subtitles found locally for video: 9KDrJ73n-F0
# Subtitles found locally for video: 6LZc7ojAi2g
# Subtitles found locally for video: oQ8AxXKD97g
# Subtitles found locally for video: Xq9ZvDve1Cc
# Subtitles processed: E68hCcUPaXo
# Subtitles found locally for video: JjRdBbfqdWM
# Subtitles found locally for video: IrwLhJe6rKU
# Subtitles found locally for video: iFliNDq5NaI
# Subtitles found locally for video: IOWWrUjuw1E
# Now processing channel: CryptosRUs
# Subtitles not (yet) available for video: AgYDXj3n9m0
# Subtitles found locally for video: iKS4CpS3xmM
# Subtitles found locally for video: gl728g0JOMg
# Subtitles found locally for video: VRC6MFZn3hs
# Subtitles found locally for video: lGOBLVb_c3k
# Subtitles found locally for video: -V19M-VoFYg
# Subtitles found locally for video: 5bpI5OX2520
# Subtitles found locally for video: 1qSfa65UGX0
# Subtitles found locally for video: pqUUVuOvH9k
# Subtitles found locally for video: xpYlzOdMFjw
# Subtitles processed: C2BzdnGWuW0
# Subtitles found locally for video: aoTwIwbHBZI
# Subtitles found locally for video: AFory2tcOeI
# Subtitles found locally for video: 0ZRZRgXRPVM
# Now processing channel: OnlyTheSAVVY
# Subtitles found locally for video: ezt6ddXOsEk
# Subtitles found locally for video: di6kwvKmPWs
# Subtitles processed: y0OxkjplX1U
# Subtitles processed: 5ANAj-8-3_E
# Subtitles found locally for video: gnRqIDdjA78
# Subtitles processed: Qe1JY7tRHCI
# Subtitles processed: BM9MMYIQ5Zo
# Subtitles not (yet) available for video: sUV3Gtam85o
# Now processing channel: MoneyZG
# Subtitles found locally for video: opRHjM_zUt0
# Subtitles found locally for video: 4iqnzZt-kGk
# Subtitles found locally for video: xdULxfNjOJY
# Subtitles found locally for video: fomGqYahw7k
# Now processing channel: SheldonEvansx
# Subtitles found locally for video: 4__C6exzzOs
# Subtitles found locally for video: C33TCtC8X4k
# Subtitles found locally for video: V-DgRB-ZuYg
# Subtitles processed: oLr9lpm7F-o
# Now processing channel: MMCryptoTube
# Subtitles found locally for video: AjjCv_n_GL4
# Subtitles found locally for video: hON-qy6MANE
# Subtitles found locally for video: Es-QgeNgBag
# Subtitles processed: L4BlByZcO4I
# Subtitles processed: 2NqSnHB-mxM
# Now processing channel: JasonPizzinoOfficial
# Subtitles found locally for video: gpn9b0Ca1RA
# Subtitles processed: Xs2F95BFfYE
# Subtitles found locally for video: joS7fp35Y-Q
# Subtitles found locally for video: 7pIduKuxHnI
# Subtitles found locally for video: EtIF4yBs4Bc
# Subtitles found locally for video: olz02dU-iy8
# Subtitles found locally for video: QmbV9QPNlbM
# Subtitles found locally for video: rBUl8rJiETQ
# Subtitles found locally for video: lThTIn0t6hU
# Now processing channel: FUDTV
# Subtitles found locally for video: s4jXS0QoFz8
# Now processing channel: BrianJungy
# Subtitles found locally for video: DhIcLfZM34U
# Subtitles found locally for video: TSlruJ3thBs
# Now processing channel: CryptoBanterGroup
# Subtitles found locally for video: f-Me3b_BX28
# Subtitles processed: OnnFtvuzI3s
# Subtitles found locally for video: b7FpI3Nub2c
# Subtitles found locally for video: yX4o9b-C8WE
# Now processing channel: JamieTree
# Subtitles found locally for video: eIY_GY3hHt8
# Subtitles found locally for video: iww09Eeql_o
# Subtitles found locally for video: 6zk461I6XGc
# Subtitles found locally for video: 15fRHTRlXAE
# Subtitles found locally for video: Cci3HcGwiXw
# Subtitles found locally for video: qgVd_yeQY18
# Now processing channel: UCjemQfjaXAzA-95RKoy9n_g
# Subtitles found locally for video: Y_rHaqnpBbk
# Subtitles processed: cKa9X8GO0KQ
# Subtitles found locally for video: 43Q6h1Eq8l0
# Subtitles processed: Q5RYGd-CX_E
# Subtitles processed: HgyMkf_81AA
# Subtitles found locally for video: Z7xz3WtVkzQ
# Subtitles found locally for video: 6LZc7ojAi2g
# Subtitles found locally for video: 1HazPkT-2zc
# Subtitles found locally for video: HVNy3lElOic
# Subtitles found locally for video: uDcPqrBvWS4
# Subtitles found locally for video: IOWWrUjuw1E
# Now processing channel: INEVITRADE
# Subtitles found locally for video: VaTaQWVGLIs
# Now processing channel: CoinBureau
# Subtitles processed: f8iPIV9cBAs
# Subtitles found locally for video: v7LyUzKWGfQ
# Subtitles found locally for video: enAoz-87D7A
# Subtitles found locally for video: TnSrjvckBTY
# Subtitles found locally for video: IrFJsQC_fik
# Subtitles found locally for video: aBnWQRs1bPQ
# Subtitles found locally for video: _ZDAZYnkugs
# Subtitles processed: Jb5RPJ_1uNs
# Subtitles found locally for video: BU6K141pU5I
# Now processing channel: TheCryptoLark
# Subtitles found locally for video: eo9amYniiN4
# Subtitles found locally for video: 7BL7UkHsWb4
# Subtitles found locally for video: Zm2CRpfDbog
# Subtitles found locally for video: NkdyNtbP2qw
# Subtitles found locally for video: eHFuCaLwqNA

# %%
coins = [
    'Bitcoin', 'Ethereum', 'Cardano', 'Solana', 'Polygon', 'Litecoin', 'Binance coin', 'Sandbox', 'Decentraland',
    'Dogecoin', 'Shiba Inu', 'Axis', 'Polkadot',
]

mentions = {coin: {} for coin in coins}

for video in data:
    for sentence in video['subtitles']:
        for coin in mentions:
            if coin.lower() in sentence.lower():
                if video['channel'] not in mentions[coin]:
                    mentions[coin][video['channel']] = []
                mentions[coin][video['channel']].append(sentence.lower().replace(coin.lower(), f"[{coin.upper()}]"))

import pandas as pd

mentions_data = []
for coin, channels in mentions.items():
    mentions_data.append({'coin': coin, 'num_channels': len(channels), 
                          'total_mentions': len(all_coin_mentions(coin, mentions))})
pd.DataFrame(mentions_data)
# Out:
#             coin  num_channels  total_mentions
# 0        Bitcoin            16            1274
# 1       Ethereum            16             619
# 2        Cardano            15             224
# 3         Solana            15             196
# 4        Polygon            10              80
# 5       Litecoin             6              12
# 6   Binance coin             3               5
# 7        Sandbox            13              97
# 8   Decentraland            10              52
# 9       Dogecoin             5              12
# 10     Shiba Inu             3               5
# 11          Axis             2               3
# 12      Polkadot             6              20

# %%
print('\n\n'.join(all_coin_mentions('Bitcoin', mentions)))
# Out:
# heck [BITCOIN]s holding up really well compared to a lot of these other a lot of these other stocks.
#
# i mean heck the nasdaq is down as much as [BITCOIN] in the last 24 hours.
#
# so i wouldn't be surprised if [BITCOIN] fell another thousand dollars or something like that.
#
# but i'm not banking on that either if we see [BITCOIN] fall down to fifty three thousand seven hundred fifty three thousand eight hundred.
#
# i think that i will be picking up some more [BITCOIN].
#
# [BITCOIN] goes up to eighty thousand dollars.
#
# you might feel fomo that you didn't have it in [BITCOIN].
#
# sam today we are looking at what just happened in the market because we saw huge sell-offs 24-hour sell-offs and [BITCOIN] or 20 20 sell-offs in [BITCOIN] more than that in a lot of other cryptocurrencies.
#
# now we have [BITCOIN] that spike down on this chart.
#
# el salvador bought 150 more [BITCOIN] hey they are looking long-term on this.
#
# everything being adopted every single bank wants a piece of [BITCOIN] or crypto and then we have the crypto market so the crypto market can kind of be like your dog when it's got too much energy it can zoom back and forth.
#
# let's look at [BITCOIN] here.
#
# i don't think we'll do anything for [BITCOIN] and crypto in the long term.
#
# na suddenly just not be interested in [BITCOIN] because it fell twenty percent.
#
# and of course it's not as beautiful and pretty as a 60 000 [BITCOIN].
#
# do i think we're gonna hit a hundred thousand dollar [BITCOIN] by the end of the year ten thousand dollar ethereum.
#
# they said that [BITCOIN] is severely overvalued ethereum is severely overvalued of course we're getting like charlie munger saying how bad cryptos are and they wish that they were never that they were never even thought of.
#
# so i bought some [BITCOIN] yesterday around.
#
# 11 p.m eastern time [BITCOIN] was around 52 000.
#
# i bought a little bit of [BITCOIN] not a lot just a little bit.
#
# or so i bought some [BITCOIN] i added more than at 11.
#
# like i said i bought more [BITCOIN] then at about midnight.
#
# and then i also bought more [BITCOIN] here today.
#
# so i want to talk about that talk to you about why metaverse is down today why the metaverse tokens are down today and give you some massive news for [BITCOIN] ethereum and all other cryptos including crypto.com.
#
# let's talk about fidelity fidelity is launching a spot [BITCOIN] etf in canada this week.
#
# and he says it will easily be the biggest asset manager to date with a [BITCOIN] etf and this is.
#
# it's almost becoming like a joke that the us won't back these [BITCOIN] etfs while a lot of other countries a lot of similar countries are actually allowing these spot [BITCOIN] etfs some some people are asking can they invest in this so it is interesting to see that the us just won't adopt and at the same time when we're getting these new spot etfs we're going through a little bit of a supply shock.
#
# but this is the [BITCOIN] on exchanges.
#
# and it just took a dip after the last couple days when we saw that drop in price where [BITCOIN] fell to 53 54 000.
#
# we're seeing a lot of [BITCOIN] flow off of exchanges now.
#
# i did a little calculation just super back of the envelope here just over the last two months since august we have lost 200 000 [BITCOIN] if you extrapolate this out a little bit.
#
# but if we had this level of accumulation we would run out of [BITCOIN] on exchanges in about 36 37 months.
#
# we have a lot less ethereum and [BITCOIN] than we had just a few months ago one other thing that i'd like to take a look at.
#
# i think that is pretty much the floor unless we see [BITCOIN] fall down to 50 000.
#
# and i think even here we could easily see a 3 5 10 x for the end of the year assuming [BITCOIN] really does get to 100 000 or so over the coming months.
#
# so if you have the voyager app and you hold enough voyager tokens you can get extra income or extra interest from other holdings like [BITCOIN] ethereum and stablecoin now this is spiked in price.
#
# the one that we all love the one that we want more of [BITCOIN].
#
# so [BITCOIN]'s rsi fell down drastically.
#
# so i think [BITCOIN] is the one asset that all these institutions want to buy all the banks are looking at adding to the balance sheet or just allowing their clients to buy it.
#
# they just bought 7k [BITCOIN] in the fiscal fourth quarter and they own one out of every 176 [BITCOIN] i believe they're going to continue to buy.
#
# is one more publicly traded company to buy some [BITCOIN] or another country to accept it as legal tender or just more of the supply shock that we're seeing now for it to go up drastically.
#
# but everyone seems to be getting a little bit more greedy now [BITCOIN]s come up from 54 000 to 58 000.
#
# and i think a lot of people will be buying [BITCOIN] and they'll be buying it over sixty thousand.
#
# i've been buying [BITCOIN] under 30..
#
# when we're in extreme fear now you can see that you you should still be invested in crypto just because of the returns this is the risk-adjusted returns of [BITCOIN] versus all other assets so basically you want to be up here.
#
# [BITCOIN] with a hundred percent [BITCOIN] is over here so risk maximum annual loss is somewhere around.
#
# and then if you include just 10 percent [BITCOIN] and 90 cash you would still be at a very good 40 return and only a max risk of about eight or nine percent.
#
# but it gives you 35 returns so anywhere on this continuum anywhere on this continuum [BITCOIN].
#
# is better so the risk goes up as time as you have more [BITCOIN] but also.
#
# your max annual return goes up dramatically so that's why i think you really need to look at [BITCOIN] as part of your portfolio because that really shows it.
#
# so they actually bought 100 [BITCOIN] the other day buying the dip on thanksgiving getting a little bit of that fire sale at 20 off sale now with [BITCOIN] being down so much from its high.
#
# i think we are bound to move up and the supply shock is only getting closer and closer if you look at how much [BITCOIN]s on exchanges or ethereum.
#
# so [BITCOIN] is the first crypto i bought.
#
# but i think [BITCOIN]'s a great one to hold long term.
#
# so if you want another good blue chip v chain is fantastic but let me know your thoughts on this down below let me know why you think crypto's falling so much even though it kind of makes sense that crypto should be going up if there's more cause for inflation in the future at least [BITCOIN] because it is an inflation hedge in a lot of people's minds.
#
# so first of all gary gensler said there's a competition for us banking uh [BITCOIN].
#
# but still he realizes that [BITCOIN] is huge and could take over the banking system now.
#
# we've already seen certain people trying to figure out how banks can hold [BITCOIN] as collateral and use it and one company that is doing a lot in that space.
#
# we will build tools to help increase access to the economy so they say as part of the rebrand a separate part of the company that's dedicated to advancing [BITCOIN] known as square crypto will change its name to spiral.
#
# today we're not seeing a lot of movement we have only about 12 or 13 cryptos that are actually up and cardano is one of them but the majority of cryptos are slightly in the red even [BITCOIN] slightly in the red a lot of cryptos just not moving much.
#
# they offer stocks [BITCOIN] gold etfs all in one retirement account.
#
# they support [BITCOIN] ethereum xrp.
#
# so let's say you invest ten thousand dollars in [BITCOIN].
#
# but if you put a thousand dollars into [BITCOIN] or ethereum and [BITCOIN] really does go up to a million dollars which i don't think is too difficult right if it goes up to a million dollars that one thousand dollars turns into twenty thousand dollars.
#
# also i just covered some big news just a little while ago talking about what whales were doing and how they were buying up [BITCOIN] and how this was really it for cryptocurrency.
#
# but we have some big news of a massive massive social media platform and the ceo stepping down to focus most likely on their new [BITCOIN] exchange.
#
# they have a new cyber monday deal where you can actually get 40 for every referral in [BITCOIN] so you can get great interest rates on voyager.
#
# and he said in the past that he thinks his life's work is going to be to work on [BITCOIN] he says there isn't anything more important in my lifetime to work on than [BITCOIN].
#
# so he is a big [BITCOIN] bull.
#
# and he is probably going to move over and focus really on his decentralized exchange for [BITCOIN] now.
#
# so i think this is actually bullish news for [BITCOIN] and crypto because he is going to continue in the space now.
#
# we know that microstrategy is actually buying [BITCOIN] they bought over 7000 [BITCOIN] just recently.
#
# [BITCOIN] saw the largest inflows in five weeks totaling 247 million coming from a launch of another investment product in europe.
#
# it makes a lot of sense and it fell down to about 30 the other day 33 now looking at each asset we have 247 million in [BITCOIN] significant amount more institutions feel comfortable with that than anything else obviously.
#
# a lot going into ethereum too not nearly as much as [BITCOIN] but a lot going into ethereum still multi-asset 9.1.
#
# i think it is good for the crypto market you can see there is a lot of money flowing in and [BITCOIN] ethereum.
#
# now of course i'm not a financial advisor this is going to fall down faster than something like ethereum or [BITCOIN] if there is a bear market.
#
# we have [BITCOIN] up 0.02.
#
# so this is a d5 protocol that gives you yield on your [BITCOIN].
#
# now they want to offer [BITCOIN] backed loans.
#
# but they don't want to use [BITCOIN] as collateral they actually want to use synthetic products like futures.
#
# and if they had a liquidation agent they were just doing secured lending without ever having [BITCOIN] touch their balance sheet now.
#
# some of this might change if the accounting principles in the u.s change i think that would change how many companies actually add [BITCOIN] to their balance sheet.
#
# i think it would explode if you didn't have to take a loss every time that [BITCOIN] falls down.
#
# but i definitely think it will push up especially if they can get this figured out if the concurrency issue is solved and multiple people can transact on uh decks at one time that would be huge and it would push up the price especially if the rest of the market goes up in price now of course if [BITCOIN] goes down to 50 000 over the next week.
#
# the [BITCOIN] really runs the market even at this point.
#
# hello welcome to the kale show this little cutie woke me up today and told me that [BITCOIN] had crashed all the way to 42 000 we are in miami.
#
# i think we need to overall hit smooch the like button if you think that crypto as a whole should probably start stop hosting events in miami because you know the [BITCOIN] conference the prize crash.
#
# is going to hold and [BITCOIN] has a way it always has a way of finding those people that are just over leveraged and over greedy right.
#
# that's what [BITCOIN] does.
#
# that we've already dealt with 46 times doing that is a recipe for disaster like if you would have sold [BITCOIN] the first time that china banned [BITCOIN] you'd be down horrendously right.
#
# the ethereum to [BITCOIN] chart.
#
# ethereum is vastly vastly vastly outperforming [BITCOIN] even in this drop and let me tell you something in the history of crypto.
#
# there's been a lot of fear in the market and traditionally in [BITCOIN].
#
# those guys are idiots right now talking about [BITCOIN].
#
# and so that sets my framework for number two which is the ethereum to [BITCOIN] chart because sure it might be a little bit worrisome if ethereum and all coins were just going crazy and everyone was super greedy right because that would signal.
#
# but when there when when there's not a lot of greed in the market right and ethereum is performing [BITCOIN] and we just dumped like like we're literally at peak fear peak fear and ethereum.
#
# is outperforming [BITCOIN] that is not what happens right last time we dumped in may right when [BITCOIN] dumped all the way from like what was it uh like like 59k all the way down to 30k.
#
# ethereum was not outperforming [BITCOIN].
#
# bullcrap omicron is bullcrap jerome powell is a liar from the from the pit of hell um the last two things the ethereum [BITCOIN] chart should not look like this if the market is topping out and the last thing what did i say uh i forgot the last thing what did i say if you're in [BITCOIN].
#
# let's get on with the show guys we have a huge show everyone on crypto twitter is doing this right now about the ethereum to [BITCOIN] chart.
#
# everyone's talking about [BITCOIN].
#
# raul paul is talking about 100 to 300 rally in [BITCOIN] toward the end of the year.
#
# it's this ethereum to [BITCOIN] chart right.
#
# so it's everything's looking fine after what he said yesterday [BITCOIN]'s looking good.
#
# this 61k level is the key okay 61k [BITCOIN] and here's the chart that pentoshi's been tweeting forever.
#
# right here they're kind of like [BITCOIN].
#
# where's [BITCOIN].
#
# i don't even care about [BITCOIN].
#
# but here's what's going to happen though in the next 48 hours in the next week depending on what [BITCOIN] does whenever [BITCOIN] reaches hold on where's [BITCOIN].
#
# okay [BITCOIN].
#
# so once [BITCOIN] is going sideways too [BITCOIN]'s like this but once [BITCOIN] reaches 61k 61k.
#
# but and hold and final note holding [BITCOIN] over ethereum is absolutely insane.
#
# they're not going to buy [BITCOIN].
#
# right you guys remember the past like few the past month has been pretty choppy with [BITCOIN] right but look at this all it's just been up and to the right up and to the right.
#
# but basically ethereum's going to get bullish people are going to get confidence in [BITCOIN] more confidence in [BITCOIN] and all coins are going to do a 5-10.
#
# just like i told you that this ethereum [BITCOIN] chart was going to be all over your timeline.
#
# november was all over the place [BITCOIN] up.
#
# [BITCOIN] down.
#
# it just follows the direction of ethereum or [BITCOIN] so if we think that ethereum is going to go up.
#
# daddy jerome's not going to let the market crash [BITCOIN]'s going to go up.
#
# okay [BITCOIN].
#
# we're going to talk about the only two things that matter i think you know what those two things are for this cycle and where we are headed next with [BITCOIN] with ethereum and with all coins so if you are excited to learn what actually matters in this market right now.
#
# look it's done this right same thing with [BITCOIN] [BITCOIN].
#
# right the first thing we're going to talk about is is the bottom in on [BITCOIN].
#
# right because if the bottom is in on [BITCOIN] and ethereum we are basically safe right.
#
# this is back when it when [BITCOIN] bottomed out at 39k and went from 39k all the way up to 69kc.
#
# he says the beat the [BITCOIN] price is bullish and ethereum is more bullish.
#
# he said [BITCOIN] sideways and ethereum and alts get room to play.
#
# big ones talking about pyr there is no way in literal hell unless [BITCOIN] takes a dump down to the crypto abyss that this thing is not going to go up because of one simple reason influencers imagine if you had a marketing team except the marketing team has like.
#
# we know we know that ethereum and [BITCOIN] is the most bullish chart in crypto right now.
#
# this wedge ethereum is going to lead the way and break out against [BITCOIN] now.
#
# that is very important because that means that eth is greater than [BITCOIN].
#
# okay eth greater than [BITCOIN].
#
# and so when ethereum breaks out against [BITCOIN] and goes parabolic what is going to go more parabolic.
#
# so we have a bottom etherium is going to go up more than [BITCOIN].
#
# and then it got listed literally the same day that [BITCOIN] dumped so we're gonna go back to this price.
#
# is the bottom in on [BITCOIN] and ethereum because if the bottom's in we are safe to buy these 11 new crypto coins which i'm going to show you on this video which i expect to get massive massive returns on the rest of the year.
#
# so the first thing we need to discuss is is the bottom end right because if the bottom is in on [BITCOIN] and ethereum.
#
# that is the same thing that's with [BITCOIN] and ethereum.
#
# but basically they make it safe for us to invest in ethereum a [BITCOIN].
#
# we have this breakout on the ethereum [BITCOIN] chart once we break this line.
#
# and it is my strong opinion that ethereum is going to lead the way the rest of this market cycle usually [BITCOIN] leads the way.
#
# pentoshi is saying that ethereum [BITCOIN] as previously stated no matter what it seems ethereum is set to outperform [BITCOIN] so if you have some [BITCOIN] you're watching this video.
#
# but if you just want to outperform your [BITCOIN] it's very simple right.
#
# which is why [BITCOIN] crashed because the normal stocks crashed.
#
# remember yesterday stock markets plunging [BITCOIN]s in the bear market.
#
# but this is the guy i trust the most when it comes to on-chain fundamentals what is the supply and the demand for the [BITCOIN] network.
#
# and he says later on in the letter that he thinks aetherium is more bullish than [BITCOIN] and that [BITCOIN] might actually chill out here in december.
#
# i could honestly see that i could see [BITCOIN] hanging out between our levels here now.
#
# which means you can make your money now while it's safe while [BITCOIN] is chilling right well as long as [BITCOIN] isn't going parabolic.
#
# even [BITCOIN] dumping doesn't even matter it's just sideways right now.
#
# i'm not saying ape your entire net worth into this because we did miss this entry however the fact that [BITCOIN] and ethereum are still kind of chilling down here.
#
# but guys we got to talk about this because ethereum to [BITCOIN] on crypto twitter right now is literally like this.
#
# hold on hold on this is us on crypto twitter right now watching the ethereum to [BITCOIN] chart isn't this.
#
# just everyone on your crypto timeline right now literally every single person is like ethereum to [BITCOIN] ethereum to [BITCOIN].
#
# i'll try to make this bigger a thousand tweets in one day with one version or another of the ethereum [BITCOIN] chart.
#
# oh my gosh kale stop showing us the ethereum [BITCOIN] chart.
#
# uh this is on [BITCOIN].
#
# it's probably gonna pull [BITCOIN] up above sixty thousand dollars.
#
# today i'm pretty sure we are going to get absolutely parabolic moves in ethereum followed by [BITCOIN] followed by all coins we'll talk about that order because that's a different order than we normally get in the markets same thing here with.
#
# i can't stop retweeting bullish ethereum to [BITCOIN] charts and here's another one john wick.
#
# [BITCOIN] right.
#
# they're only talking about how the price of [BITCOIN] determines everything.
#
# he's been talking about how the ethereum to [BITCOIN] ethereum.
#
# is following the [BITCOIN] chart.
#
# so what i would like to propose to you guys who's watching this video is that ethereum is going to take the place of [BITCOIN] this cycle it's going to do what [BITCOIN] did in 2017..
#
# okay let's just start off with with the data as you can see here the line the white line is the [BITCOIN] line from 2017 and the blue line is the ethereum line from from right now.
#
# we think ethereum is going to follow [BITCOIN] from 2017..
#
# so what does that mean let's go to the [BITCOIN] chart.
#
# okay if we go back to [BITCOIN] from 2017 what actually happened with [BITCOIN] because if we can just assume in our heads that okay ethereum's going to do it [BITCOIN] in 2017..
#
# okay november 30th on the [BITCOIN] chart from 2017 is right here.
#
# then nine thousand dollar [BITCOIN] that would have been nice to buy that.
#
# impossible [BITCOIN] [BITCOIN] right [BITCOIN]'s not going to go from 58 000 to a 97 gain would be 120 k.
#
# so they they know that [BITCOIN] did 98.
#
# right now we're at let's say 58k [BITCOIN] right here.
#
# 58k [BITCOIN] right btc.
#
# what is this 120k [BITCOIN].
#
# we're not gonna get to 120k [BITCOIN] by december 17th.
#
# this crazy gain right here isn't going to happen in [BITCOIN].
#
# so the big dogs are literally they're literally choosing between if they're literally choosing between eath and [BITCOIN].
#
# sure which one's more realistic 120k [BITCOIN] or nine thousand dollar ethereum.
#
# because what's interesting is that [BITCOIN] topped out on december 17th.
#
# so all coins went a lot crazier than [BITCOIN].
#
# we did a 97 game just in [BITCOIN] in this six week in this in 17 days from this point in 2017 and the fact that ethereum is following [BITCOIN] perfectly from 2017 makes me think that it is not unrealistic at all at all to get ten thousand dollar ethereum by the middle of january.
#
# in ethereum okay not in [BITCOIN].
#
# this is like the dump that we saw in [BITCOIN] right again following [BITCOIN] you see this dump this dump scared the pants off of people.
#
# and so that's what i think is going to play out in the cycle for everyone's like what's going to happen with [BITCOIN] honestly.
#
# i think [BITCOIN]'s a little bit too big.
#
# this is [BITCOIN].
#
# my face is in the way i honestly think this might be the time where [BITCOIN] kind of detaches sure there might be you know when ethereum dumps that one day there might be some of this stuff.
#
# and and we've seen this already hold on let me just show you because we saw this bounce on the [BITCOIN] chart.
#
# whatever you guys know what happened the past few days with [BITCOIN] right the price went up because they they.
#
# so we're seeing [BITCOIN] kind of stabilize and we're seeing ethereum really start to charge and.
#
# [BITCOIN] goes up then.
#
# what we're going to see in two situations is [BITCOIN] kind of dabble around and just make that big charge to 100k which i think it's gonna stop at like 75 80k.
#
# or we could just be seeing ethereum taking off right now [BITCOIN] dying off.
#
# these aren't [BITCOIN]s or ethereums.
#
# welcome back everybody to altcoin daily [BITCOIN] and cryptocurrency are dumping make sure you watch the entire video.
#
# [BITCOIN] has fallen 10 today touching 51 600 with ethereum dipping even more touching four thousand dollars and the greater cryptocurrency market falling even more to a large extent ladies and gentlemen do not be fooled they are propagating certain stories like this to scare people away to get people to have fear uncertainty and doubt and in this video i'm going to show you some of the things that caused this dump and reasons why i think this dip this dip that you're looking at right here is a trap i am still bullish i still believe that [BITCOIN] ethereum are in bull markets.
#
# charlie munger seemingly going on a press run again flooding [BITCOIN] fudding cryptocurrency of course charlie munger as you know is partner with warren buffett partner at berkshire hathaway charlie munger.
#
# praises china for banning cryptocurrency charlie munger saying i wish [BITCOIN] had never been invented either this man is insanely out of touch.
#
# he realizes that the world is changing in big ways in addition to this negative rhetoric around [BITCOIN] and cryptocurrency.
#
# the sec has rejected one of the many spot [BITCOIN] etfs again.
#
# their spot [BITCOIN] etf has just started trading today in canada canadians can now get direct exposure to [BITCOIN] through fidelity's spot exchange traded fund guess what they have a proposal to do exactly this in america.
#
# is have you gotten your [BITCOIN] back credit card yet.
#
# this is a great credit card you could earn an unlimited 1.5 back in [BITCOIN] on every purchase.
#
# altcoin daily cc use the link in the description one card more [BITCOIN] every single purchase you make chipotle mcdonald's groceries.
#
# [BITCOIN] dominance is dropping all coins are exploding left and right.
#
# may we told people not to sell your [BITCOIN] not to sell your xrp uh your cardano your ethereum.
#
# [BITCOIN] dominance is dropping all coins are exploding left and right.
#
# i want to just remind the audience that altcoins for the most part follow [BITCOIN].
#
# so if [BITCOIN] has a red month it's very likely that altcoins uh are going to follow or at least not have as big of gains as usual.
#
# my final question to you ben is if your analysis or if your get thoughts are [BITCOIN] can reach 100k.
#
# a 2x is a 15x really possible if [BITCOIN] only hits 100k.
#
# right [BITCOIN] was you know in between.
#
# if [BITCOIN] goes up in general all coins go up but look at what solana did look at what avalanche has been doing look what krypto.com has been doing.
#
# we were we're big [BITCOIN]ers.
#
# all right welcome back everybody to altcoin daily my name's austin in today's video i want to share with you the latest news involving [BITCOIN] involving ethereum involving the metaverse like decentraland like axi and much more if you're interested in making money with cryptocurrency click subscribe we drop a video every single day demystifying this cryptocurrency market.
#
# the united states is the one that has destabilized more countries and destabilized their own u.s dollar by printing and printing more money way more than [BITCOIN].
#
# the point is that while [BITCOIN] fundamentals are still strong i'll show you the data in a second and while if either of these two things happen or get bigger then that would be a cause for markets to dip none of this has actually happened yet but because of headlines like those we're at extreme fear in the market right now sentiment is quite low but moving forward.
#
# the social data the thanksgiving dump caught many off guard this year as [BITCOIN] dropped below 54 000 for the first time since.
#
# october 6th interest in buying the dip has subsequently spiked indicating the crowd isn't too phased by this recent volatility and this shows just how many people socially on social media outlets are tweeting about buying the dip huge spike in volume from this price point and while you may be waiting maybe you're hoping that [BITCOIN] drops a little bit lower.
#
# el salvador celebrates black friday and buys another 100 btc for that 20 off dip with the addition of those 100 coins el salvador now holds 1220 [BITCOIN] worth roughly 63 million dollars following [BITCOIN]'s recent drop and here was.
#
# that exact tweet from the president el salvador just bought the dip 100 extra coins acquired with a discount hashtag [BITCOIN].
#
# this is the first time in crypto's history where we have nation states aggressively accumulating announcing that they bought the dip think about that and the final thing before we talk altcoins that i want to show you is a little perspective on where we are in the [BITCOIN] cycle.
#
# and they are a better way to [BITCOIN] join the fastest growing global cryptocurrency exchange with the lowest fees around.
#
# it'll be released in a few days but a black friday [BITCOIN] crash just happened.
#
# thousands and thousands and thousands of developers not officially working for ethereum but building their own tools projects everything on ethereum if you're spending billions of dollars a year even if you're spending billions of dollars a year that is a really hard thing to surpass network effects again props to andreas antonopoulos he didn't think ethereum would be able to surpass [BITCOIN] for that reason i thought that ethereum was enough of a jump that it would um all these new coins i don't think there's enough of a jump there to surpass the technological network effects.
#
# and i'm not sure how many in in this room i actually should buy a show of hands how many people hold [BITCOIN] not bad not bad.
#
# i want to share with you the latest news involving cardano involving xrp involving lower cap altcoins and of course what's happening with [BITCOIN] if you're interested in making money with cryptocurrency.
#
# explaining that central banks all over the world are screwed they're screwed if they stop printing money and they're also screwed if they keep printing more money and while all this is happening the [BITCOIN] network is only getting bigger.
#
# and i'm not sure how many in in this room i actually should buy a show of hands how many people hold [BITCOIN] not bad not bad.
#
# a big [BITCOIN] could go to zero for me.
#
# if you measured your world in [BITCOIN] you would see what i'm talking about you'll see deflation forever.
#
# yes i get it the crypto market is dipping today but [BITCOIN] isn't a bubble.
#
# thanks sponsor of the channel the block 5 [BITCOIN] rewards credit card introducing the block 5 rewards visa signature credit card where you can earn an unlimited 1.5 back in [BITCOIN] on every single purchase and what differentiates this card from the handful of competitors out there is with this card there is no annual fee which i like there are no foreign transaction fees which i love.
#
# and if you use our link get 3.5 back on every single purchase in [BITCOIN] during your first three months.
#
# think about this when you buy groceries this week some of you will be earning 1.5 back in [BITCOIN] and some of you won't which one are you gonna be.
#
# he's a new [BITCOIN] bull.
#
# they're not quite ready to buy [BITCOIN] directly but investing in a crypto business.
#
# but first i want to take 60 seconds and give a big thank you to sponsor of this episode the block 5 [BITCOIN] rewards credit card introducing the blockfy rewards visa signature credit card where you can earn an unlimited 1.5 back in [BITCOIN] on every single purchase.
#
# you can earn [BITCOIN] back.
#
# you can earn 3.5 back one card more [BITCOIN] and trusted around the world with more than 500 000 people 350 institutions and if we look at the payouts of what people have been earning in just the last 60 days card holders have earned over 120 [BITCOIN] in credit card rewards in just the last two months that is blockfy.com altcoindailycc link down below and moving forward to our final clip listen to cesi.
#
# so uh and because of his non-diversification he's not into [BITCOIN] or crypto.
#
# so that's an interesting thing that you know we'll definitely monitor uh during the bear market when it hits but in general like when your grandma is asking you how to buy [BITCOIN] not because you told her like.
#
# that's a good sign right because your grandma's asking you how to buy [BITCOIN].
#
# but if you've never mentioned the word [BITCOIN] or ethereum to your grandma then your grandma shows up to thanksgiving and says by the way.
#
# well we have we have price targets that we're looking at we're looking at a hundred thousand dollars for [BITCOIN].
#
# your larger plan of taking profits as a strategy it works better to kind of either dollar cost average out over a period of time or to have different price targets and just be okay if [BITCOIN] goes up to 250k.
#
# you know you can actually uh like let's say [BITCOIN] goes to 100 000 during this bull market.
#
# so you bought a [BITCOIN] you bought a [BITCOIN] at ten thousand dollars a year ago.
#
# or uh 13 14 months ago [BITCOIN] at ten thousand dollars.
#
# you buy one [BITCOIN] it goes up to.
#
# but if you take one [BITCOIN] at 10 000 it hits a hundred thousand dollars.
#
# just made four [BITCOIN] now when the price goes up.
#
# but if it's 100 000 for [BITCOIN] you know start looking at it.
#
# and you you know you believe in maybe the next [BITCOIN] or.
#
# but if you can do that that makes a lot of sense in a bear market right but staking [BITCOIN] and ethereum and or less coins for instance staking a depreciating asset to earn more money that is also depreciating like i don't think it's the most effective way to use your money.
#
# like make sure if you're gonna do the lending that you know the ins and outs of the loan that you're getting and that you're protected against liquidation if the price drops 90 85 is the average drop for [BITCOIN] in a bear market.
#
# and that's just [BITCOIN] average altcoin loss is probably 97 they almost all were down 97 at some point during uh you know probably early 2019.
#
# so is it time to panic about [BITCOIN].
#
# so i'm here to address in a very special friday night stream of whether or not you should be panicking about [BITCOIN] so thanks for tuning in as always smash the like subscribe to the channel two streams almost every day 11 30 and 8 30 pm central standard time.
#
# welcome uh you know what maybe it's time to dust off the good old cap and uh and switch to plan c because [BITCOIN] is now at 53 000..
#
# so what's going on with [BITCOIN].
#
# [BITCOIN] always gets through it.
#
# so [BITCOIN] may be facing some difficulties now.
#
# but even with all this with all the negativity and everything [BITCOIN] is still holding strong at 53 000.
#
# but [BITCOIN] will continue.
#
# that is look forward to [BITCOIN] hitting a hundred thousand this cycle this year and let's do it together.
#
# a thing [BITCOIN] fell to like i don't know.
#
# that's why [BITCOIN] fell down down to like 51 now recovered at 53..
#
# and uh she still remains very bullish on [BITCOIN].
#
# but she believes in [BITCOIN] web 3.0 what el salvador is doing and how [BITCOIN] will still get to 500 000.
#
# so really in the next four years she believes [BITCOIN] will still get to 500 000 right so follow the smart money follow these big players wall street type people and pay attention to what they're doing girls gals like kathy wood um made a fortune with tesla and other tech stocks.
#
# and she believes [BITCOIN] is definitely the future.
#
# i mean honestly uh [BITCOIN] dominance still didn't move.
#
# focus [BITCOIN].
#
# so what's going on with [BITCOIN] today.
#
# but if you're a [BITCOIN] holder wait for this at this moment.
#
# that is and also talk about what's going on with [BITCOIN] and crypto today.
#
# and uh and i think a lot of people are forgetting that if you if you just zoom out a little bit uh you'll notice that [BITCOIN] was actually lower just one week ago when [BITCOIN] went down to about 53 54-53 and even touched upon 53-3 before making a big recovery so when in doubt zoom out because this was only last week.
#
# there's always going to be corrections just like when [BITCOIN] was stuck around 40 000.
#
# that's when [BITCOIN] started recovering and headed up in a big way.
#
# so this is why you have to have patience investing any kind of investing including [BITCOIN] you two have to have patience the key to make money is basically outlasting someone else who's impatient they're transferring their wealth to you when they sell and you buy.
#
# because if you do zoom out you realize that [BITCOIN] is still within this channel.
#
# it's actually looking like exactly what happened last time when [BITCOIN] first hit about 53 000.
#
# it wait for this because we can have that reversal where [BITCOIN] starts going up to the top of the channel right before the end of this year.
#
# [BITCOIN]'s not gonna go away.
#
# and i'm going to cover why [BITCOIN]'s not gonna go away today.
#
# the main topic is of course uh [BITCOIN].
#
# they're the ones that hold the enormous amount of [BITCOIN] and earn a lot of [BITCOIN]s every single day and.
#
# uh we have gone through many many periods where it seems like [BITCOIN].
#
# just know that yes [BITCOIN] goes up sometimes.
#
# and you just have to have patience even this one look this time when [BITCOIN] went from 64 remember.
#
# and i know some of you guys if not most of you guys lived through that too during those days when i was streaming it was really really depressing hard to motivate people because people thought that [BITCOIN]s would fall back down to 10 000 at that point.
#
# uh us covet vaccinations spike of several states confirm omicron cases so this is the latest thing that's been causing [BITCOIN] to come down first of all omicron.
#
# was this detected in south africa brought [BITCOIN] down.
#
# and then we had had one a few days ago or yesterday where uh first case in the u.s was detected brought [BITCOIN] down.
#
# and now we have multiple states detecting uh this and that has brought down [BITCOIN] a little bit more.
#
# uh he hates [BITCOIN] hates crypto will never get around to it.
#
# and uh and to quote him of course i hate [BITCOIN] success.
#
# he called buying [BITCOIN] as unethical as harvesting freshly uh freshly harvested baby brains.
#
# that's how much he hates [BITCOIN].
#
# or there's jealous of the tremendous gains that people have made right [BITCOIN].
#
# that's all from [BITCOIN].
#
# well let's talk about fundamentals of [BITCOIN].
#
# right the public trade companies that continue to buy more and more and more and hold more and more and more because they are that confident about [BITCOIN] in the past.
#
# we've heard of miners selling a lot of [BITCOIN] because they're trying to pay for the operations.
#
# they just added another 256 [BITCOIN]s to their reserve they mined 256 [BITCOIN]s in november all november.
#
# now they hold 5242 [BITCOIN]s right.
#
# they're not selling anything and not only that they're taking a loan against their [BITCOIN].
#
# so this five five thousand two thousand five thousand two hundred forty two [BITCOIN]s they're using that as collateral and borrowing more money and using that to buy more miners and minting or cr mining more [BITCOIN].
#
# how much [BITCOIN]s they they hold has gone up and.
#
# one [BITCOIN] miner terawolf raises 200 million in debt at equity guess why right they're raising that because they want to expand and add more miners they're basically following the same footsteps of michael sailor.
#
# so it's funny every single miner is doing this you know um basically selling stock or bonds or borrowing against their [BITCOIN].
#
# help contribute securing the [BITCOIN] network and michael saylor argues that every single time a miner goes public it makes [BITCOIN] stronger so this is a giant piece of [BITCOIN]'s fundamentals right uh the hash rate now has almost fully recovered since the china banned back in may june july.
#
# half the hash power of [BITCOIN] was pushed out of one country distributed across the world and now months later we have basically fully recovered from that because of these miners in north america and miners across the world that continue this arms race to solve this [BITCOIN] equation and to accumulate as many [BITCOIN]s as they can right so the fundamentals of [BITCOIN] one of the big fundamentals of [BITCOIN] [BITCOIN] mining hash rate securing the network.
#
# so if you're worried about [BITCOIN] short term just know that [BITCOIN] short term can be volatile.
#
# so that's what i want to talk about with [BITCOIN].
#
# there's a couple other things i want to talk about today if you're looking at live coin watch [BITCOIN] dominance is still below 40.
#
# i know that [BITCOIN] came down a little bit.
#
# the rest of the all points came down a little bit but the ratio of all coins to [BITCOIN] did not go down in fact it stayed again.
#
# and i bring this up all the time when [BITCOIN] dominance does not shoot up that means generally retail investors like you.
#
# and i are not panic selling when there's true blood in the street when there's true panic [BITCOIN] dominance.
#
# or you buy low so that is a very very important metric that will continue to show [BITCOIN] dominance did not go up at all.
#
# right now is more deflationary than [BITCOIN].
#
# it's lower than [BITCOIN]s right now.
#
# somewhere in the article it shows that ethereum's inflation rate right now is about 0.86 percent compared to [BITCOIN]s about 1.6.
#
# so if you look at it that way it's actually more deflationary than [BITCOIN] although ethereum does not have set.
#
# cap [BITCOIN] does right.
#
# yet and when you have doubt zoom out because you'll see that [BITCOIN] is doing just fine.
#
# and we're still stuck in this channel which is actually a good thing because when [BITCOIN] is ready to go it could really go afterwards but remember focus on the fundamentals focus on the future and have patience all right lastly before i get into q.
#
# argue that [BITCOIN] may have not gone up this much at all.
#
# and uh all the billionaires causing a whole bunch of commotion and putting their money into [BITCOIN] right.
#
# so you could argue that had we not had a pandemic [BITCOIN] wouldn't be as big as is now right.
#
# it's [BITCOIN] for sure.
#
# but the one thing that will last the test of time is [BITCOIN] so that is the reason why how do you feel about clover finance their bid for a pair chain auction.
#
# that's what you need to have um when it comes to [BITCOIN] and.
#
# what happened with [BITCOIN].
#
# let's just start with [BITCOIN] and.
#
# i mean equities market was plus 400 500 went down to like negative 260 and [BITCOIN] came down with it.
#
# but the good thing is despite [BITCOIN] coming back down this.
#
# a day right [BITCOIN] is still holding uh unfortunately it stopped us once again.
#
# we're also going to have a christmas uh like no other because a [BITCOIN] we've been waiting for four years four long years okay outside of 2021.
#
# right so there are some good movers but overall today still a lot of red because of [BITCOIN] coming down.
#
# 100 square mostly to convert it into a crypto play into a [BITCOIN] plate.
#
# right without actually just calling it you know [BITCOIN] square or something like that like.
#
# warren buffett said [BITCOIN] is rap poison squirt.
#
# and you know that his life mission now is to basically integrate crypto [BITCOIN] payments uh even nfts and everything all into this one company called block right and.
#
# i think it's going to be bullish for [BITCOIN] in the long run.
#
# and also i saw this travis king kling excuse me highlighted all the significant stuff that happened in november despite most people concentrating on the fact that oh [BITCOIN] didn't skyrocket in november.
#
# oh [BITCOIN] didn't hit 98 000.
#
# this is why there's no fear right now uh being in [BITCOIN] and in crypto because the big money has already started.
#
# people are bashing november being a bad month for [BITCOIN].
#
# right now i guess it's because [BITCOIN] decided to go down.
#
# a few days ago right [BITCOIN] was about to come above 60 thousand today.
#
# [BITCOIN] tanked equities market tanked everything tanked and this was already.
#
# and we are going to see [BITCOIN] and crypto go higher in december in my opinion and according to my sources.
#
# and [BITCOIN] is looking pretty darn good today and all coins are looking even better.
#
# and i do believe one of the things to expect is [BITCOIN] is going to head to a hundred thousand dollars.
#
# so you can see that [BITCOIN] is a little bit higher than yesterday 58 4.
#
# but i do believe that is the path for [BITCOIN] in december.
#
# a lot of [BITCOIN] got set packed by a couple of things.
#
# i mentioned about it being the most bullish one just check out the history of [BITCOIN] in december.
#
# but whatever [BITCOIN] is set set to go higher and and not just because it's the last year of the month.
#
# everything else that i can show you about [BITCOIN] right is pointing upwards all the metrics the fundamentals adoption usage and global awareness attention.
#
# no there's just a lot of things going for [BITCOIN].
#
# and uh besides [BITCOIN] if you check out the rest of the market outstanding outstanding um you know ethereum is closing in at its new high uh binance coin.
#
# is wrong and this is tracking uh this is tracking [BITCOIN] since 2010 all the way until now right looking at the [BITCOIN] circuit supply the the having events the total supply putting all that together.
#
# he made that prediction utilizing his floor model and that was back when [BITCOIN] was 30 000..
#
# and he could still be right for december which he predicted with his floor model that [BITCOIN] will be at 135 000 which is not too far off from his hundred thousand prediction with stock to flow.
#
# so i still believe this is in play now uh outside of plan b tech dev interesting looking at the eight hour uh time frame for [BITCOIN] looking at a couple things.
#
# of course a important indicator for whether or not [BITCOIN] is oversold or over bought right and putting it all together putting it all together.
#
# they're very very very heavily involved with [BITCOIN] and very uh they're very bullish on [BITCOIN].
#
# they have their custodial service they have their trading desk too for institutions and now they are launching a spot [BITCOIN] etf in canada.
#
# already has three spot [BITCOIN] etfs purpose.
#
# but fidelity is even a bigger name so this could bring even more attention and more money to [BITCOIN] and institutional investors that want to invest in [BITCOIN] without worrying about custody service and all that stuff.
#
# the sec didn't allow a [BITCOIN] spot etf to be approved.
#
# but you know what grayscale tells that well at least their lawyer uh tells uh over twitter that they don't think that sec has any leg to stand on the fact that they approve [BITCOIN] futures etfs but not spot etfs that's a big no-no.
#
# well we could see a [BITCOIN] spot etf in the us in the near future probably not this month but maybe early 2022 in january or february.
#
# these [BITCOIN] futures etfs launch.
#
# is that they're afraid that you know [BITCOIN] is still too manipulative or people are manipulating it.
#
# but still uh you know we have [BITCOIN] futures out.
#
# we have [BITCOIN] futures etf.
#
# i mean and [BITCOIN] is worldwide.
#
# so [BITCOIN] is mature.
#
# again uh if we do get a [BITCOIN] spot etf.
#
# that means stuff like this because i think jack dorsey really really really wants to utilize square not only to grow it but grow it into a crypto payment system right cash app which allows you to buy [BITCOIN] right now upgraded so that it supports tap root which is the newest upgrade for [BITCOIN] which has increased.
#
# but we know that square itself with all the terminals and dongles out there they haven't opened up [BITCOIN] payments yet or crypto payments.
#
# jack is very very very involved with [BITCOIN].
#
# he has a whole team in fact that he hired he's paying out of pocket just to work on [BITCOIN].
#
# which means he's basically all in on [BITCOIN] right now.
#
# lastly in croatia if you're from croatia this will be a big positive their largest supermarket now accepts [BITCOIN] and xrp surprising enough not just [BITCOIN] and xrp.
#
# one ready for december ready for [BITCOIN] at a hundred thousand dollars.
#
# but the biggest one of the biggest mistakes i had was when [BITCOIN] fell down to 3 100.
#
# you know it's one of those situations you know [BITCOIN].
#
# is not gonna go much lower when [BITCOIN] fell to 3100 in uh 2018.
#
# hold good amount of [BITCOIN] and all coins you'll be fine but a lot of times.
#
# oh i go all into all coins if there's a correction you go hate yourself because all coins also correct a lot worse than [BITCOIN].
#
# [BITCOIN] is coming back.
#
# well that's why i'm here to address and also talk about why they rallied in the first place and of course i have to talk about [BITCOIN] which seemed like it was going to shatter 60 000 this morning and came a little bit down.
#
# [BITCOIN] looks like it wants to break out.
#
# dow dropped 600 points immediately right after that and also [BITCOIN] fell down from about 59.3 down right.
#
# so this is why i say this is a big endorsement for [BITCOIN].
#
# this is the reason why people the billionaires out there and investment companies and hedge funds why they buy [BITCOIN].
#
# i should say institutions uh why they're buying [BITCOIN] as a hedge as as a hedge right against inflation as a store of value and why no one is really buying gold these days because gold has not been a good hedge for the last decade.
#
# maybe yes it's not that all that good because people panic sold everything equities and [BITCOIN] and brought it down.
#
# but long term you know this is fantastic for [BITCOIN].
#
# this is why people hold [BITCOIN] and why it will continue to rally and.
#
# this is what i always stress every single day whenever [BITCOIN] comes down a little bit.
#
# michael saylor accumulated uh 120 000 [BITCOIN]s for microstrategy that's never going to come back on the market ever.
#
# and he himself holds 20 000 [BITCOIN]s and that's just one man and one company.
#
# you how healthy [BITCOIN] is and how how it go higher because this simple is simply a supply and demand right.
#
# and then you look at this [BITCOIN].
#
# if you're a [BITCOIN] holder if you're a crypto holder i don't think you have anything to worry about today's little dip.
#
# if inflation fears uh you know is real then why would you not get into [BITCOIN].
#
# so that's [BITCOIN] but.
#
# ...
#
# the purpose part is pretty comical the first wave of coins promised to be a better [BITCOIN] the second wave of coins promised to be a better ethereum the third and current wave of coins are promising to be a better uni swap rv maker dow chain link axe infinity or something else.
#
# it's what made [BITCOIN] so successful after all and speaking of satoshi if the founder of an altcoin can't be identified and it's not a privacy coin it might be a coin with one honorable exception of course.
#
# cto paolo arduino told the blog that the demand for usdt has been impacted due to a significant decrease in open interest for [BITCOIN] futures this will be relevant later so keep it in mind in terms of why protos published this piece on tether the faq notes that quote we chose this endeavor to present the crypto ecosystem with the most extensive and transparent research on exactly who buys tether to date in terms of why this matters quote realizing the scope of the forces that work in crypto markets specifically those with usdt pairs equips those who trade cryptocurrencies with knowledge to make more informed decisions so with this context in mind we can finally unpack protos's tether papers the report begins with a big pie chart which breaks down the biggest buyers of.
#
# it's received nearly 700 million dollars of usdt from tether over the years most of this digital dry powder has been invested into [BITCOIN] and d5 tokens such as uni swap sushi swap compound and rv.
#
# the thing is that protos doesn't specify exactly what it means by quote giant crypto bull run if this is in reference to a [BITCOIN] bull.
#
# [BITCOIN]'s price has consequently been sluggish now if you want to deeper dive into just how much of an effect futures trading can have on the crypto market you can check out my video about that in the description.
#
# the cio of arcana assets who said cardano isn't on par with competing smart contract platforms despite all their talk coin bureau also pointed out in great detail that the advanced ut xo model also known as the extended utxo model or e utxo model which as you may have known is the lower version or original version of this model being used on the cardano [BITCOIN] exchange platform coin bureau then goes on in detail about how the system works and applies more modern experience to the term.
#
# bullish on [BITCOIN].
#
# well then you have to know about some of the stocks that i'm going to talk about today stocks that won't only give you exposure to [BITCOIN] but the crypto market as a whole stocks that could be insanely undervalued based on some sound fundamentals so if you're looking for alpha beyond the crypto markets this video is for you [music].
#
# so if you're long-term bullish on crypto then coinbase stock could be an attractive play moving on though i want to take a look at a stock that can give you exposure to the crypto markets through a different angle [BITCOIN] miners are not only fundamental to the security of the network.
#
# this is the owner and operator of north america's single largest [BITCOIN] mine that based in rockdale texas riot blockchain is now one of the world's largest public [BITCOIN] miners following this acquisition when it comes to the numbers riot.
#
# this of course gives it additional exposure to the price of [BITCOIN] the majority of these coins were mined just this year now like coinbase riot released third quarter results that missed analysts expectations and hence drove the stock price considerably lower the company posted a slight loss of 16 cents per share when the consensus estimates were for earnings of 35 cents per share.
#
# i said that it would be one of the best things for the long-term health of the [BITCOIN] network while there was a massive fall in hashrate post.
#
# were incredibly low mainly as a result of their reliance on coal-powered power plants this meant that chinese miners could still remain profitable even if we saw large falls in the price of [BITCOIN] as happened back in the 2018 crypto winter.
#
# the point of the matter is that riot blockchain is uniquely positioned in the u.s [BITCOIN] mining landscape.
#
# now what's important to note about riot blockchain or any other miner for that matter is that its profitability is inherently tied to the price of [BITCOIN] although the current price of [BITCOIN] is well above riot's average cost to mine of 34k.
#
# it helps that jack is a massive proponent of [BITCOIN] and the power of crypto.
#
# that's most exciting for me ever since 2014 when square allowed sellers to accept [BITCOIN] in its online stores it's been looking for ways to further capitalize on crypto the most profitable move so far.
#
# has been the move to include [BITCOIN] purchases and selling in its cash app.
#
# the cash app generated 1.8 billion dollars in [BITCOIN] revenue this is up from 11 last year and over the past two years [BITCOIN] revenue and gross profit grew 250 and 343 respectively on a cagr basis but this is only the tip of the iceberg when it comes to what square is doing in the cryptocurrency space.
#
# firstly you have the fact that square has actually allocated [BITCOIN] to its balance sheet as a treasury asset in the fourth quarter of 2020.
#
# it invested 50 million dollars and then in the first quarter of this year invested a further 170 million dollars now while this does give square direct exposure to the price of [BITCOIN].
#
# that the likes of microstrategy have however this does mean that square won't have to deal with some of the massive mark-to-market accounting swings that microstrategy has to beyond just simple [BITCOIN] purchases and balance sheet allocation square.
#
# another really impressive [BITCOIN] initiative by square is that it will be building a quote [BITCOIN] focused business division according to this tweet by jack dorsey.
#
# this division inside square recently released a white paper for a decentralized [BITCOIN] exchange this will be called the tb dex.
#
# this would provide a fiat bridge whereby people could easily get in and out of [BITCOIN] sending it to their friends in a permissionless manner.
#
# some of you may indeed be asking guy if i was bullish on [BITCOIN] why wouldn't i just buy [BITCOIN].
#
# but you don't own a stake in a company that's able to make money from [BITCOIN] a company that could make that money even if [BITCOIN] falls by five percent tomorrow and a company that could in future distribute some of those profits to you on an ongoing basis in the form of dividends when it comes to coinbase.
#
# is a bit more of a speculative play on the strength of north american [BITCOIN] mining.
#
# add to that that it owns the largest [BITCOIN] mine in america.
#
# and it's well positioned to benefit from a [BITCOIN] boom.
#
# it's less dependent on the [BITCOIN] markets and allows you to gain a stake in a company with healthy financial performance in the trad fire space.
#
# there is one simple reason why the price of [BITCOIN] is just going to keep going up.
#
# i'll be discussing that in today's video also micro strategy seems to be completely addicted to buying [BITCOIN] also some big nft news for you too so make sure to watch the whole video to get all of the goods.
#
# you can go out and get your own personal domain johnsmith.[BITCOIN].
#
# now let's talk about the price of [BITCOIN] our favorite topic the price of [BITCOIN] what is [BITCOIN] doing today.
#
# [BITCOIN] did come up very close here to um the descending line of resistance here this key trend line that is kind of the area i really really want to see [BITCOIN] crush above we came up pretty close to retesting that we didn't quite get there.
#
# well then i think we're going to get back into a more bullish territory for [BITCOIN].
#
# then we might be in for some more bearish price action heading forward for [BITCOIN] but we have not done that in fact we did beautiful bounce off it as we talked about in yesterday's video now.
#
# then we start talking about nailing some new all-time highs for b get [BITCOIN] getting past of course the 69 thousand dollar tops.
#
# but uh yeah that's what we're watching right now on the technicals for [BITCOIN] also.
#
# we've seen a lot of bullish narratives building the market we've seen a lot of money coming in and buying [BITCOIN] the amount of [BITCOIN] on exchanges.
#
# for the most part it's just down meaning that people are buying [BITCOIN] taking off exchanges dumping in their cold wallets.
#
# it's gone those people who are buying [BITCOIN] at fifty five sixty thousand dollars.
#
# these guys are getting property staking a claim taking that long-term view that [BITCOIN] will be a million dollar asset one of these days of course hundred thousand dollars first obviously obviously before we start getting too high on the moon juice here.
#
# it was the shallowest correction this year and in terms of an overall [BITCOIN] bull market correction on the shallower end of them now let's talk about some quick nft news before we dive into the big stuff for today amc and sony.
#
# obviously amc has been you know getting all kinds of uh up in the business of the crypto scene they started um taking cryptocurrency payments for tickets so they're gonna take [BITCOIN].
#
# you know they actually have value in of themselves and can to an extent anyway move on their own in relation to what [BITCOIN] is doing in the market but.
#
# this guy just can't stop stacking [BITCOIN] you see regular people they stack sets right because [BITCOIN] is uh expensive these days.
#
# it's not every person that can just run out and buy a [BITCOIN] just one [BITCOIN] for a lot of people that's a heck of a lot of money micro strategy they buy [BITCOIN] by the hundreds or the thousands.
#
# well they just bought another 7 000 freaking [BITCOIN] micro strategy man holy cow holy cow they have like 121 000 [BITCOIN] or something like that absolute craziness.
#
# i'm telling you the corporate play of the year when [BITCOIN] is worth a million dollars a piece.
#
# they're just gonna keep buying more [BITCOIN].
#
# i wonder if they're going for 210 000 [BITCOIN] that would be a significant chunk of the supply.
#
# let's talk about the simple fact why [BITCOIN] is going to keep going up.
#
# and it doesn't look pretty holy cow holy cow of course opt out by [BITCOIN].
#
# you know there's a reason why [BITCOIN] is just going to keep going up over time because fiat is just going to keep going down.
#
# wouldn't you want to be holding basically the world's best inflation hedge [BITCOIN].
#
# i know i do because of the insanity of fiat [BITCOIN].
#
# in that world i want to hold [BITCOIN].
#
# i like what mcdiesel says here by the way i may literally never sell my [BITCOIN].
#
# that is how winning is done get your [BITCOIN] hold on to it.
#
# it is the best exchange for longing and shorting a wide range of the top cryptocurrencies [BITCOIN] ethereum cardano solana.
#
# which is this beautiful breakout that ethereum is having versus [BITCOIN].
#
# this is going to send ethereum soaring versus [BITCOIN] assuming of course that this breakout does hold i think we're gonna see ethereum closing a lot of distance between it and [BITCOIN] in terms of total valuation.
#
# this is back early 2020 ever since that time it's just been down down down down down down down much like [BITCOIN].
#
# i think that was our peak [BITCOIN] peak ethereum moments we're never going to see that much ethereum on exchanges ever again.
#
# this is the equivalent of three [BITCOIN] happenings happening at one freaking time that's nuts man.
#
# spot [BITCOIN] spot ethereum etfs the us keeps pushing futures based etfs on people which are just an inherently inferior product compared to what the market actually wants which is a spot etf product but ethereum futures.
#
# i think because we already have [BITCOIN] futures we will get.
#
# so the arc crypto portfolio is 40 ethereum 60 [BITCOIN] so there's still more [BITCOIN] heavy.
#
# we can see the coin based trading volume also showing that ethereum not [BITCOIN] has been the preferred purchase of big money players that is a very very important distinction to make because coinbase is where the institutional money is buying their crypto and they are doing bigger volumes of ethereum than [BITCOIN] the big money they like ethereum.
#
# [BITCOIN] man it has been [BITCOIN]ing over the last few days.
#
# some big [BITCOIN] news coming out of singapore some fun memes too.
#
# i remember buying [BITCOIN] right around here.
#
# [BITCOIN].
#
# this is a mega mega important trend line here for [BITCOIN] seeing.
#
# and realistically there's two key areas i want to see the price of [BITCOIN] closing above one is this trend line right here.
#
# so i want to see the price of [BITCOIN] closing above that that could be the launch pad that we need because that break out of the downtrend.
#
# essentially the [BITCOIN] is in right now that would be the launch pad that we would need to crack this right here this purple box that is the bull bear front line of the battle underneath this we're still stuck in that downtrend.
#
# i love it [BITCOIN].
#
# the news media man these guys are hilarious so [BITCOIN] tumbles 20 from record highs earlier this month entering a bear market see in traditional markets when an asset goes down by 20 it enters a bear market.
#
# this framework doesn't really apply to cryptocurrencies because a 20 tumble can happen in a single freaking day for [BITCOIN].
#
# so i guess on that day [BITCOIN] entered a bear market on one day come come on news media.
#
# is [BITCOIN]'s down 20 from its its recent top but on friday we saw a lot of all coins down 20 30 some great buying opportunities and when this happens you always see people.
#
# how human psychology works just wonder if shares one with you too this is a funny one of course the united states dollar printing away and all the politicians out there wagging their fingers [BITCOIN]s destabilized in the financial system it's become the scapegoat for central bankers and all this stuff trying to push blame away from the insane money branding the money printing the the the wild criminality happening at central banks and the the dirty incestuous relationship between central bankers politicians and big financial banks.
#
# it's gross and they're going to blame [BITCOIN] for all the ills of the world.
#
# those guys are funny nice bit of news to share with some more serious stuff guys some nice news to share with you [BITCOIN] now processing processing more dollar value than paypal it could surpass mastercard by 2026 at the current trajectory.
#
# nice one [BITCOIN] obviously.
#
# the more we see layer twos coming on board for [BITCOIN] more lightning network and stuff like that the more value will get processed because it'll bring the fees down and make transactions very very quick you have to realize a [BITCOIN] transaction still costs some dollars.
#
# no one's using the [BITCOIN] main chain man.
#
# so this is pretty cool to see [BITCOIN] of course the network will continue settling more value over time as the market grows and expands now what's interesting too.
#
# um it's pretty cool to see the [BITCOIN] processing more dollar value than paypal.
#
# in fact uh ethereum on average is settling three times more value on chain every single day in fact some days that's four times the value settled on chain every single day than [BITCOIN] ethereum man.
#
# and that's in spite of the crushing ethereum fees that we see right now final news story for today two [BITCOIN] funds have launched in singapore.
#
# it's not a [BITCOIN] etf.
#
# uh it is a fund for these um higher net worth individuals to have a regulated vehicle to be able to invest in [BITCOIN].
#
# so this is a very positive thing i'm happy to see these [BITCOIN] funds being launched in singapore that allows bunch of basically asian whale money another avenue to get involved in crypto and.
