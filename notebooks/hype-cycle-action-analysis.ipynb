# %%
import pickle

with open('hc-actions.pkl', 'rb') as f:
    actions = pickle.load(f)

# %%
import pandas as pd
from hypecommons import plot, plt

# plt.rcParams["figure.figsize"] = (5, 4)

FEES = 0.00075

data = []

for action in actions:
#     print(action)
    data.append({
        'sell_time': action['params']['sell_time_at_10th'],
        'freq': action['data']['search_res']['freq'],
        'close_rmse': action['data']['search_res']['score'],
        'gain': action['params']['gain_at_10th'],
        'gained': action['params']['gain_at_10th'] > FEES,
    })
#     break

df = pd.DataFrame(data)
df = df.set_index('sell_time')
df
# Out:
#                      freq  close_rmse      gain  gained
# sell_time
# 2021-11-21 23:57:00     1    0.029240 -0.001270   False
# 2021-11-22 00:05:00     5    0.024034  0.009272    True
# 2021-11-22 00:26:00     1    0.018735 -0.001402   False
# 2021-11-22 00:50:00     5    0.029391  0.020401    True
# 2021-11-22 01:01:00     1    0.021481 -0.005972   False
# ...                   ...         ...       ...     ...
# 2021-11-23 23:18:00     1    0.022852  0.007811    True
# 2021-11-24 00:00:00    15    0.024750 -0.003505   False
# 2021-11-24 00:27:00     3    0.023044  0.000000   False
# 2021-11-24 00:37:00     1    0.026945 -0.001489   False
# 2021-11-24 01:00:00    15    0.029380 -0.019159   False
#
# [100 rows x 4 columns]

# %%
high_low_avg_var = []

for action in actions:
    if True:# action['params']['gain_at_10th'] > FEES:
        hlav = ((dfs['high'] - dfs['low']) / dfs['low'] / action['data']['search_res']['freq'] * 100).mean()
        high_low_avg_var.append(hlav)
        print((action['params']['gain_at_10th'], hlav))
        dfs = action['data']['df_sell'].iloc[:8]
        dfs[['low', 'high']].plot()
        plt.show()
        dfs['volume'].rolling(window=3).mean().plot()
        plt.show()
#     break
# Out:
# (-0.0012702078521938636, 0.44941740760645177)
# (0.009271523178807906, 0.05431955139940229)
# (-0.0014018691588785577, 0.8457796228796487)
# (0.020400934509005906, 0.034439117632481)
# (-0.0059718916977234875, 3.403976353571016)
# (-0.0021913109756099376, 0.1116602746421764)
# (-0.0007462686567165014, 0.09473578909956001)
# (0.002735199332559062, 0.09347891951841589)
# (-0.0027475323089447804, 0.1474416102050423)
# (-0.038631518743825734, 0.05888529241434054)
# (0.013203005324969002, 0.5413315022797447)
# (0.0, 0.4548725431689859)
# (-0.008410416757140238, 0.03332343482155814)
# (0.0005202913631634298, 1.214273319451125)
# (0.0005789829200039915, 0.09849208298948292)
# (-0.005742263056092882, 0.09710175930817594)
# (0.0051698670605613214, 1.0646675349573043)
# (-0.001679543164259385, 0.02781212732574814)
# (-0.0013325718636969996, 0.05344890251386053)
# (-0.01375814627081834, 0.007799428321475524)
# (0.0012000000000000437, 0.1423547627978103)
# ...

# %%
df['hlav'] = high_low_avg_var
df
# Out:
#                      freq  close_rmse      gain  gained      hlav
# sell_time
# 2021-11-21 23:57:00     1    0.029240 -0.001270   False  0.449417
# 2021-11-22 00:05:00     5    0.024034  0.009272    True  0.054320
# 2021-11-22 00:26:00     1    0.018735 -0.001402   False  0.845780
# 2021-11-22 00:50:00     5    0.029391  0.020401    True  0.034439
# 2021-11-22 01:01:00     1    0.021481 -0.005972   False  3.403976
# ...                   ...         ...       ...     ...       ...
# 2021-11-23 23:18:00     1    0.022852  0.007811    True  0.172332
# 2021-11-24 00:00:00    15    0.024750 -0.003505   False  0.029961
# 2021-11-24 00:27:00     3    0.023044  0.000000   False  0.150290
# 2021-11-24 00:37:00     1    0.026945 -0.001489   False  0.204986
# 2021-11-24 01:00:00    15    0.029380 -0.019159   False  0.008177
#
# [100 rows x 5 columns]

# %%
df.plot.scatter(x='close_rmse', y='hlav', c=['blue' if x else 'red' for x in df['gained']])
# Out:
# <AxesSubplot:xlabel='close_rmse', ylabel='hlav'>
